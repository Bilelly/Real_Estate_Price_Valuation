# %%
import pandas as pd

# %%
#library imports API data
#import

# %%
# Region: Haut-Rhin (68)
df_locations = pd.read_csv('../data/ech_annonces_locations_68.csv',sep=';')
df_ventes = pd.read_csv('../data/ech_annonces_ventes_68.csv',sep=';')

# %%
df_locations.head()
# Out:
#               idannonce type_annonceur typedebien typedetransaction  etage  \
# 0  immo-facile-52417007             pr          m                 l      0
# 1    ag672097-382986683             pr          a                 l      3
# 2    ag672097-383464082             pr          a                 l      1
# 3    ag680864-383044166             pr          a                 l      0
# 4    ag672097-380998252             pr          a                 l      2
#
#    surface  surface_terrain  nb_pieces  prix_bien  prix_maison  ...     date  \
# 0      116              NaN          5       1250          NaN  ...  2023-04
# 1       44              NaN          3        600          NaN  ...  2023-04
# 2       53              NaN          2        498          NaN  ...  2023-04
# 3       41              NaN          2        460          NaN  ...  2023-04
# 4       74              NaN          4        695          NaN  ...  2023-04
#
# ...

# %%
df_locations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11702 entries, 0 to 11701
# Data columns (total 52 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   idannonce                11702 non-null  object
#  1   type_annonceur           11702 non-null  object
#  2   typedebien               11702 non-null  object
#  3   typedetransaction        11702 non-null  object
#  4   etage                    11702 non-null  int64
#  5   surface                  11702 non-null  int64
#  6   surface_terrain          507 non-null    float64
#  7   nb_pieces                11702 non-null  int64
#  8   prix_bien                11702 non-null  int64
#  9   prix_maison              0 non-null      float64
#  10  prix_terrain             0 non-null      float64
#  11  mensualiteFinance        11702 non-null  int64
#  12  balcon                   11702 non-null  int64
#  13  eau                      11702 non-null  int64
# ...

# %%
df_ventes.head()
# Out:
#                 idannonce type_annonceur typedebien typedetransaction  etage  \
# 0  hektor-robischung-2862             pr          a                 v      0
# 1          apimo-82452515             pr          m                 v      0
# 2    immo-facile-52471952             pr          m                 v      0
# 3    immo-facile-52477215             pr          a                 v      0
# 4      ag681088-383601401             pr          m                 v      0
#
#    surface  surface_terrain  nb_pieces  prix_bien  prix_maison  ...  UU2010  \
# 0       64              NaN          3     128400          NaN  ...   68113
# 1       85           4950.0          4     189000          NaN  ...   68000
# 2      187           3182.0          9     282900          NaN  ...   68000
# 3       76              NaN          4      79000          NaN  ...   68000
# 4       90           3071.0          5     317000          NaN  ...   68000
#
# ...

# %%
df_ventes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27737 entries, 0 to 27736
# Data columns (total 59 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   idannonce                27737 non-null  object
#  1   type_annonceur           27737 non-null  object
#  2   typedebien               27737 non-null  object
#  3   typedetransaction        27737 non-null  object
#  4   etage                    27737 non-null  int64
#  5   surface                  27737 non-null  int64
#  6   surface_terrain          11444 non-null  float64
#  7   nb_pieces                27737 non-null  int64
#  8   prix_bien                27737 non-null  int64
#  9   prix_maison              437 non-null    float64
#  10  prix_terrain             437 non-null    float64
#  11  mensualiteFinance        27737 non-null  int64
#  12  balcon                   27737 non-null  int64
#  13  eau                      27737 non-null  int64
# ...

# %%
df_unified = pd.concat([df_locations, df_ventes], ignore_index=True)

# %%
df_unified.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39439 entries, 0 to 39438
# Data columns (total 59 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   idannonce                39439 non-null  object
#  1   type_annonceur           39439 non-null  object
#  2   typedebien               39439 non-null  object
#  3   typedetransaction        39439 non-null  object
#  4   etage                    39439 non-null  int64
#  5   surface                  39439 non-null  int64
#  6   surface_terrain          11951 non-null  float64
#  7   nb_pieces                39439 non-null  int64
#  8   prix_bien                39439 non-null  int64
#  9   prix_maison              437 non-null    float64
#  10  prix_terrain             437 non-null    float64
#  11  mensualiteFinance        39439 non-null  int64
#  12  balcon                   39439 non-null  int64
#  13  eau                      39439 non-null  int64
# ...

# %%
#df_unified.to_csv('../data/processed/dataset_unifie.csv', index=False)
