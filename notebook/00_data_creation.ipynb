# %%
import pandas as pd

# %%
#library imports API data
#import

# %%
# Region: Paris (75)
df_locations = pd.read_csv('../data/df_annonces_gps_iris_locations_75.csv',sep=';')
df_ventes = pd.read_csv('../data/df_annonces_gps_iris_ventes_75.csv',sep=';')
# Out:
# C:\Users\CYTech Student\AppData\Local\Temp\ipykernel_1140\969437883.py:2: DtypeWarning: Columns (19,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_locations = pd.read_csv('../data/df_annonces_gps_iris_locations_75.csv',sep=';')
# C:\Users\CYTech Student\AppData\Local\Temp\ipykernel_1140\969437883.py:3: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ventes = pd.read_csv('../data/df_annonces_gps_iris_ventes_75.csv',sep=';')

# %%
df_locations.head()
# Out:
#                    idannonce type_annonceur typedebien typedetransaction  \
# 0  century-21-202_2864_10012             pr          a                 l
# 1  century-21-202_2864_10010             pr          a                 l
# 2         ag757532-513493781             pr          a                 l
# 3         ag752861-512430734             pr          a                 l
# 4         ag752352-513486446             pr          a                 l
#
#    etage  surface  surface_terrain  nb_pieces  prix_bien  prix_maison  ...  \
# 0      0       74              NaN          3       2790          NaN  ...
# 1      2      113              NaN          4       3840          NaN  ...
# 2      2       34              NaN          1       1650          NaN  ...
# 3      5       72              NaN          3       3380          NaN  ...
# 4      4       29              NaN          1       1090          NaN  ...
#
#       date  INSEE_COM  IRIS  CODE_IRIS  TYP_IRIS_x TYP_IRIS_y  GRD_QUART  \
# ...

# %%
df_locations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111901 entries, 0 to 111900
# Data columns (total 52 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   idannonce                111901 non-null  object
#  1   type_annonceur           111901 non-null  object
#  2   typedebien               111901 non-null  object
#  3   typedetransaction        111901 non-null  object
#  4   etage                    111901 non-null  int64
#  5   surface                  111901 non-null  int64
#  6   surface_terrain          174 non-null     float64
#  7   nb_pieces                111901 non-null  int64
#  8   prix_bien                111901 non-null  int64
#  9   prix_maison              0 non-null       float64
#  10  prix_terrain             0 non-null       float64
#  11  mensualiteFinance        111901 non-null  int64
#  12  balcon                   111901 non-null  int64
# ...

# %%
df_ventes.head()
# Out:
#               idannonce type_annonceur typedebien typedetransaction  etage  \
# 0    iad-france-1999597             pr          a                 v      4
# 1        apimo-86694012             pr          a                 v      2
# 2        apimo-86677654             pr          a                 v      2
# 3    ag756339-511400033             pr          a                 v      4
# 4  hektor-equinimo-6700             pr          a                 v      1
#
#    surface  surface_terrain  nb_pieces  prix_bien  prix_maison  ...  UU2010  \
# 0       70              NaN          4     820000          NaN  ...     851
# 1      155              NaN          6    1990000          NaN  ...     851
# 2      155              NaN          6    1990000          NaN  ...     851
# 3       55              NaN          3     665000          NaN  ...     851
# 4       63              NaN          3     659000          NaN  ...     851
#
# ...

# %%
df_ventes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170181 entries, 0 to 170180
# Data columns (total 59 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   idannonce                170181 non-null  object
#  1   type_annonceur           170181 non-null  object
#  2   typedebien               170181 non-null  object
#  3   typedetransaction        170181 non-null  object
#  4   etage                    170181 non-null  int64
#  5   surface                  170181 non-null  int64
#  6   surface_terrain          1821 non-null    float64
#  7   nb_pieces                170181 non-null  int64
#  8   prix_bien                170181 non-null  int64
#  9   prix_maison              1 non-null       float64
#  10  prix_terrain             1 non-null       float64
#  11  mensualiteFinance        170181 non-null  int64
#  12  balcon                   170181 non-null  int64
# ...

# %%
df_unified = pd.concat([df_locations, df_ventes], ignore_index=True)

# %%
df_unified.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 282082 entries, 0 to 282081
# Data columns (total 59 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   idannonce                282082 non-null  object
#  1   type_annonceur           282082 non-null  object
#  2   typedebien               282082 non-null  object
#  3   typedetransaction        282082 non-null  object
#  4   etage                    282082 non-null  int64
#  5   surface                  282082 non-null  int64
#  6   surface_terrain          1995 non-null    float64
#  7   nb_pieces                282082 non-null  int64
#  8   prix_bien                282082 non-null  int64
#  9   prix_maison              1 non-null       float64
#  10  prix_terrain             1 non-null       float64
#  11  mensualiteFinance        282082 non-null  int64
#  12  balcon                   282082 non-null  int64
# ...

# %%
#df_unified.to_csv('../data/dataset_unifie.csv', index=False)
